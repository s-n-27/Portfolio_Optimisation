# %% [markdown]
# ## Portfolio optimization using Genetic Algorithm

# %% [markdown]
# ### Problem Statement and Data used for the Problem:
#
#    Suppose we have identified N financial assets that we wish to invest in, such as stocks, funds, bonds, or ETFs. Each asset has a historical return, which refers to the relative price difference between two periods, such as days, weeks, or months. Our objective is to construct an investment portfolio that comprises a mixture of several assets, and allocate a fraction x of total capital to each asset, which is known as the weight. The aim of portfolio optimization is to determine the optimal weights for each asset that maximizes returns and minimizes risk while adhering to certain constraints.
#
#    #### Given Data:
# Monthly Closing Stock values of MRF, Infosys, Reliance, Coal India, SBI and Titan from June 2015 to June 2018.

# %% [markdown]
# #### Theoretical Approach for the Problem used:
#
#
# Firstly, the data for the monthly closing stock values of MRF, Infosys, Reliance, Coal India, SBI and Titan are combined into a single dataframe. Historical returns for different periods ranging from 3 months to 36 months are then calculated for each of the stocks. The next step is to define the genetic algorithm terms - Gene and Chromosome. Gene is a scalar, which represents a fraction of the total capital assigned to a stock, whereas a Chromosome is a 1D array consisting of a set of genes, i.e., fractions of total capital assigned to each stock. It is essential to ensure that the sum of each chromosome is equal to one.
#
# After defining the Gene and Chromosome, the next step is to generate an Initial Population, which is a 2D array consisting of randomly generated chromosomes. The fitness function is then defined, which calculates the Sharpe ratio, S. The Sharpe ratio is a measure that quantifies the performance of the portfolio by maximizing return and minimizing risk simultaneously. It is computed as the difference between the portfolio return and the risk-free rate, divided by the standard deviation of the returns. The fitness function uses the mean portfolio return, risk-free rate, and the standard deviation of the portfolio return to calculate the Sharpe ratio.

# %%
import numpy as np
import pandas as pd
from functools import reduce
import matplotlib.pyplot as plt

# %% [markdown]
# #### Combine the data into a single dataframe after reading it.

# %%
files=['MRF.csv','INFOSYS.csv','RELIANCE.csv','COAL.csv','SBI.csv','TITAN.csv']
dfs=[]
for file in files:
    temp=pd.read_csv("data\\" + file)
    temp.columns=['Date',file.replace('.csv','')]
    dfs.append(temp)
stocks = reduce(lambda left,right: pd.merge(left,right,on='Date'), dfs)
print(stocks.shape)
stocks.head()
# Out:
# (37, 7)
#         Date      MRF  INFOSYS  RELIANCE    COAL     SBI    TITAN
# 0  June 2018  2108.05   266.05    1271.3  896.80  560.55  1847.20
# 1   May 2018  2136.15   271.60    1367.6  923.50  480.15  1744.80
# 2   Apr 2018  1944.60   281.45    1400.6  872.65  528.15  1765.70
# 3   Mar 2018  1891.45   255.90    1311.9  740.20  495.40  1424.65
# 4   Feb 2018  1883.80   265.10    1319.1  728.75  535.35  1519.13

# %% [markdown]
# #### Historical Returns for 3 months, 6 months, 12 months, 24 months and 36 months for each stock.
#
# The calculation for the overall return of a stock involves adding the increase in its price with any dividends distributed and then dividing it by the initial price of the stock.

# %%
def hist_return(months):
    idx=[]
    df=pd.DataFrame()
    for mon in months:
        temp=(stocks.iloc[0,1:] - stocks.iloc[mon,1:])/(stocks.iloc[mon,1:])
        idx.append(str(mon)+' Month Return ')
        df=pd.concat([df, temp.to_frame().T], ignore_index=True)
    df.index=idx
    return df    

hist_stock_returns=hist_return([3,6,12,24,36])
hist_stock_returns
# Out:
#                        MRF   INFOSYS  RELIANCE      COAL       SBI     TITAN
# 3 Month Return    0.114515  0.039664 -0.030947  0.211564   0.13151  0.296599
# 6 Month Return    0.125163  0.011212  0.011417  0.194062 -0.017957  0.368094
# 12 Month Return   0.275866 -0.178478  0.129783  0.330899  0.010911  0.562537
# 24 Month Return   0.792712  0.084237  0.274461  0.255179 -0.265911   0.44833
# 36 Month Return   0.974847  0.266844  0.069614  0.399938 -0.358785  0.447535

# %% [markdown]
# Define **Gene** (Scalar): A fraction of the total capital assigned to a stock. Lets address them as weights.

# %%
gene = np.random.rand()
gene
# Out:
# 0.7676184222220578

# %% [markdown]
# Defining Chromosome (1D Array): Set of genes i.e. fractions of total capital assigned to each stock. Set of weights.
#
# It is a 1D array consisting of fractional values representing each stock, with the sum of all fractions not exceeding 1. To create a chromosome, we will generate 6 fractional values, one for each company stock.
#
# Why should the sum be equal to 1? This is because we assume that the total capital invested in the portfolio is 1 unit, and the fractional values represent the proportion of the total capital assigned to each stock.
#
# To ensure that the sum equals 1, we can generate 6 random numbers and calculate a factor that is equal to 1 divided by the sum of these random numbers. Finally, we can multiply each of the generated random numbers with this factor, which will result in a sum of 1.

# %%
def chromosome(n):
    ch = np.random.rand(n)
    return ch/sum(ch)

child=chromosome(6)
print(child)
print("Sum = ", sum(child))
# Out:
# [0.08246532 0.25410275 0.07112765 0.15085058 0.22202455 0.21942915]
# Sum =  1.0

# %% [markdown]
# Generating Initial Population

# %%
n=6 
pop_size=100 

population = np.array([chromosome(n) for _ in range(pop_size)])
print(population.shape)
# Out:
# (100, 6)

# %% [markdown]
# The fitness function is defined as the Sharpe ratio, which measures the performance of the portfolio. It is calculated using the following formula:
#
#             S = (µ − r)/σ
#
# where µ is the mean portfolio return over a specified period, r is the risk-free rate over the same period, and σ is the standard deviation of the returns over the specified period.
#
# The mean portfolio return is calculated as the product of the mean return and the fractions of total capital assigned to each stock (chromosome).
#
# The risk-free rate is set to 0.0697 (as per Google).
#
# The standard deviation of the portfolio return is calculated as the square of the product of the chromosome and the standard deviation, plus the covariance of the respective weights in the chromosome.

# %% [markdown]
# Calculating Mean, Standard deviation and covariance of the Historical stock returns.

# %%
cols=hist_stock_returns.columns
hist_stock_returns[cols] = hist_stock_returns[cols].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# Covariance of Returns

# %%
cov_hist_return=hist_stock_returns.cov()
for i in range(6):
    cov_hist_return.iloc[i][i]=0
    
cov_hist_return
# Out:
#                MRF   INFOSYS  RELIANCE      COAL       SBI     TITAN
# MRF       0.000000  0.045393  0.027916  0.024127 -0.079078  0.014362
# INFOSYS   0.045393  0.000000 -0.000718  0.004381 -0.023178 -0.005554
# RELIANCE  0.027916 -0.000718  0.000000  0.002510 -0.013841  0.007330
# COAL      0.024127  0.004381  0.002510  0.000000 -0.011042  0.005700
# SBI      -0.079078 -0.023178 -0.013841 -0.011042  0.000000 -0.007211
# TITAN     0.014362 -0.005554  0.007330  0.005700 -0.007211  0.000000

# %% [markdown]
# Mean of Returns

# %%
mean_hist_return=hist_stock_returns.mean()
print (mean_hist_return)
# Out:
# MRF         0.456621
# INFOSYS     0.044696
# RELIANCE    0.090865
# COAL        0.278328
# SBI        -0.100047
# TITAN       0.424619
# dtype: float64

# %% [markdown]
# Standard Deviation

# %%
sd_hist_return=hist_stock_returns.std()
print (sd_hist_return)
# Out:
# MRF         0.400340
# INFOSYS     0.159583
# RELIANCE    0.119189
# COAL        0.086091
# SBI         0.204405
# TITAN       0.099615
# dtype: float64

# %% [markdown]
# Calculating Expected Portfolio Return and Portfolio Variance.

# %% [markdown]
# Expected Return

# %%
def mean_portfolio_return(child):
    return np.sum(np.multiply(child,mean_hist_return))

print("Expected Return = ", + mean_portfolio_return(population[0]))

def var_portfolio_return(child):
    part_1 = np.sum(np.multiply(child,sd_hist_return)**2)
    temp_lst=[]
    for i in range(6):
        for j in range(6):
            temp=cov_hist_return.iloc[i][j] * child[i] * child[j]
            temp_lst.append(temp)
    part_2=np.sum(temp_lst)
    return part_1+part_2

print("Portfolio Variance = ", + var_portfolio_return(population[0]))
# Out:
# Expected Return =  0.17565123448387654
# Portfolio Variance =  0.00415809447366056

# %% [markdown]
# Fitness Function

# %%
def fitness_fuction(child):
    rf= 0.0697 
    return (mean_portfolio_return(child)-rf)/np.sqrt(var_portfolio_return(child))

fitness_fuction(population[7])
# Out:
# 1.80334987862872

# %% [markdown]
# Defining a function that selects the elite population: it filters out the chromosomes with the highest returns, which were previously calculated in the fitness function.

# %%
def Select_elite_population(population, frac=0.3):
    population = sorted(population,key = lambda x: fitness_fuction(x),reverse=True)
    percentage_elite_idx = int(np.floor(len(population)* frac))
    return population[:percentage_elite_idx]

print(len(Select_elite_population(population, frac=0.3)))

[fitness_fuction(x) for x in population][:3]
# Out:
# 30
# [1.6430805132652728, 1.1552979831031893, 1.4823331980392513]

# %% [markdown]
# The mutation function performs changes to a chromosome. It selects two random numbers between 0 and 5, and then swaps the corresponding elements in the chromosome.

# %%
def mutation(parent):
    child=parent.copy()
    n=np.random.choice(range(6),2)
    while (n[0]==n[1]):
        n=np.random.choice(range(6),2)
    child[n[0]],child[n[1]]=child[n[1]],child[n[0]]
    return child

mutation(population[1]),population[1]
# Out:
# (array([0.40387664, 0.09708486, 0.18367254, 0.0198317 , 0.15947091,
#         0.13606335]),
#  array([0.40387664, 0.09708486, 0.15947091, 0.0198317 , 0.18367254,
#         0.13606335]))

# %% [markdown]
# Crossover: The heuristic crossover, also known as blend crossover, uses the fitness values of two parent chromosomes to determine the direction of the search, moving from the worst parent to the best parent.
#
# The offspring are generated using the following equation:
#
#         Offspring A = Best Parent + β * (Best Parent − Worst Parent)
#         Offspring B = Worst Parent - β * (Best Parent − Worst Parent)
#
# Where β is a random number between 0 and 1. This type of crossover is effective for real-valued genomes.

# %%
def Heuristic_crossover(parent1,parent2):
    ff1=fitness_fuction(parent1)
    ff2=fitness_fuction(parent2)
    diff=parent1 - parent2
    beta=np.random.rand()
    if ff1>ff2:
        child1=parent1 + beta * diff
        child2=parent2 - beta * diff
    else:
        child2=parent1 + beta * diff
        child1=parent2 - beta * diff
    return child1,child2

# %% [markdown]
# A function that creates a new generation of chromosomes by performing mutation, mating, or crossover based on a given probability.

# %%
def next_generation(pop_size,elite,crossover=Heuristic_crossover):
    new_population=[]
    elite_range=range(len(elite))
    while len(new_population) < pop_size:
        if len(new_population) > 2*pop_size/3: 
            mutate_or_crossover = np.random.choice([0, 1], p=[0.9, 0.1])
        else:
            mutate_or_crossover = np.random.choice([0, 1], p=[0.6, 0.4])
        if mutate_or_crossover:
            indx=np.random.choice(elite_range)
            new_population.append(mutation(elite[indx]))
        else:
            p1_idx,p2_idx=np.random.choice(elite_range,2)
            c1,c2=crossover(elite[p1_idx],elite[p2_idx])
            new_population.extend([c1,c2])
    
    for i in range(len(new_population)):
        for j in range(6):
            if new_population[i][j] < 0:
                new_population[i][j] = 0
            if new_population[i][j] > 0.25:
                new_population[i][j] = 0.25

    for i in range(len(new_population)):
        temp = sum(new_population[i])
        for j in range(6):
            new_population[i][j] = new_population[i][j]/temp
    
    return new_population

elite=Select_elite_population(population)

# %% [markdown]
# The process of mutation, crossover, and selection of the next generation is repeated until there is no improvement in the maximum returns or minimum risk, or for a fixed number of iterations.

# %%
n=6 
pop_size=100 
population = np.array([chromosome(n) for _ in range(pop_size)])

elite = Select_elite_population(population)

iteration=0 
Expected_returns=0
Expected_risk=1

returns_list = []
risk_list = []

while ( (Expected_returns < 0.30 and Expected_risk > 0.0005) or iteration <= 100 ):
    print('Iteration:',iteration)
    population = next_generation(100,elite)
    elite = Select_elite_population(population)
    Expected_returns=mean_portfolio_return(elite[0])
    Expected_risk=var_portfolio_return(elite[0])
    print('Expected returns of {} with risk of {}\n'.format(Expected_returns,Expected_risk))
    iteration+=1
    returns_list.append(Expected_returns)
    risk_list.append(Expected_risk)

print('Optimal Solution Reached or Number of Maximum Iterations Reached')
# Out:
# Iteration: 0
# Expected returns of 0.12053406078074669 with risk of 0.0002352865693500735
#
# Iteration: 1
# Expected returns of 0.18391393444691095 with risk of 0.001185690500177334
#
# Iteration: 2
# Expected returns of 0.15751498439524664 with risk of 0.00045712787574583597
#
# Iteration: 3
# Expected returns of 0.13903577209891899 with risk of 0.0002549089970916201
#
# Iteration: 4
# Expected returns of 0.14644671047619748 with risk of 0.000376381993371421
#
# Iteration: 5
# Expected returns of 0.1367493356748571 with risk of 0.0002567263941927137
#
# Iteration: 6
# Expected returns of 0.131671679357863 with risk of 0.00017647103134023432
#
# Iteration: 7
# Expected returns of 0.12989729390060017 with risk of 0.0001614455051347349
#
# Iteration: 8
# Expected returns of 0.1295215926636829 with risk of 0.00015932517053311897
#
# Iteration: 9
# Expected returns of 0.12912188065462304 with risk of 0.0001573226097786361
#
# Iteration: 10
# Expected returns of 0.1290613381154747 with risk of 0.0001574287713481835
#
# Iteration: 11
# Expected returns of 0.13292951673986256 with risk of 0.00018393995686888983
#
# Iteration: 12
# Expected returns of 0.13424563570076994 with risk of 0.00019324728312663294
#
# Iteration: 13
# Expected returns of 0.13433792406849188 with risk of 0.00019394283818384601
#
# Iteration: 14
# Expected returns of 0.13444600629673953 with risk of 0.00019547595706320003
#
# Iteration: 15
# Expected returns of 0.13449553321378457 with risk of 0.00019706126108656394
#
# Iteration: 16
# Expected returns of 0.13547252980021107 with risk of 0.00020386237485402626
#
# Iteration: 17
# Expected returns of 0.13497972953721202 with risk of 0.0002016013842645395
#
# Iteration: 18
# Expected returns of 0.1350483018915568 with risk of 0.00020203993712592395
#
# Iteration: 19
# Expected returns of 0.13485705380160296 with risk of 0.000201218969439536
#
# Iteration: 20
# Expected returns of 0.1349901000344516 with risk of 0.00020399700529910927
#
# Iteration: 21
# Expected returns of 0.13521748982140747 with risk of 0.00020611669291136295
#
# Iteration: 22
# Expected returns of 0.1343028499708161 with risk of 0.00020091337714460162
#
# Iteration: 23
# Expected returns of 0.13442456693157928 with risk of 0.0002035879734286197
#
# Iteration: 24
# Expected returns of 0.13530585867379044 with risk of 0.0002104389808761896
#
# Iteration: 25
# Expected returns of 0.1359984870965506 with risk of 0.00021574825996895346
#
# Iteration: 26
# Expected returns of 0.13597529180238635 with risk of 0.0002160949395065134
#
# Iteration: 27
# Expected returns of 0.13567602694130998 with risk of 0.00021484750951761972
#
# Iteration: 28
# Expected returns of 0.13739603498474298 with risk of 0.00022638947529753962
#
# Iteration: 29
# Expected returns of 0.13746523580553194 with risk of 0.00022699410633973335
#
# Iteration: 30
# Expected returns of 0.13752133978769893 with risk of 0.00022747936707220688
#
# Iteration: 31
# Expected returns of 0.13755011986553572 with risk of 0.00022775414209329475
#
# Iteration: 32
# Expected returns of 0.13746142494020458 with risk of 0.00022722135912094966
#
# Iteration: 33
# Expected returns of 0.1374857169501321 with risk of 0.00022743141036986152
#
# Iteration: 34
# Expected returns of 0.1374952163841382 with risk of 0.00022752990098987014
#
# Iteration: 35
# Expected returns of 0.13749850959596183 with risk of 0.00022757853918422503
#
# Iteration: 36
# Expected returns of 0.13750942914356068 with risk of 0.00022767197321202186
#
# Iteration: 37
# Expected returns of 0.13750108427063729 with risk of 0.0002276313268754519
#
# Iteration: 38
# Expected returns of 0.13749838769009354 with risk of 0.00022762474334781999
#
# Iteration: 39
# Expected returns of 0.13748109208165515 with risk of 0.00022751716143888222
#
# Iteration: 40
# Expected returns of 0.1374804097154747 with risk of 0.00022751894134260923
#
# Iteration: 41
# Expected returns of 0.13747986817229926 with risk of 0.00022752011905673424
#
# Iteration: 42
# Expected returns of 0.1374736059959247 with risk of 0.00022748161218256058
#
# Iteration: 43
# Expected returns of 0.13746880175270806 with risk of 0.000227451991276717
#
# Iteration: 44
# Expected returns of 0.13746837827938566 with risk of 0.00022745112287215607
#
# Iteration: 45
# Expected returns of 0.1374674267527788 with risk of 0.0002274461663823793
#
# Iteration: 46
# Expected returns of 0.13746743769433545 with risk of 0.0002274475472813231
#
# Iteration: 47
# Expected returns of 0.13747139952465684 with risk of 0.0002274750101945713
#
# Iteration: 48
# Expected returns of 0.13747207492794605 with risk of 0.0002274802605789928
#
# Iteration: 49
# Expected returns of 0.13747002990567295 with risk of 0.000227467058979928
#
# Iteration: 50
# Expected returns of 0.13746954580070414 with risk of 0.00022746419623425902
#
# Iteration: 51
# Expected returns of 0.1374683923351718 with risk of 0.0002274567387488451
#
# Iteration: 52
# Expected returns of 0.13746221453062285 with risk of 0.00022741548803042327
#
# Iteration: 53
# Expected returns of 0.13746699998080975 with risk of 0.00022744778913714667
#
# Iteration: 54
# Expected returns of 0.13746343682705064 with risk of 0.00022742400801166202
#
# Iteration: 55
# Expected returns of 0.13746243628014262 with risk of 0.0002274173875126415
#
# Iteration: 56
# Expected returns of 0.1374617605075762 with risk of 0.00022741292901920073
#
# Iteration: 57
# Expected returns of 0.13746028089174972 with risk of 0.0002274030545858438
#
# Iteration: 58
# Expected returns of 0.13746392398548352 with risk of 0.0002274275481415648
#
# Iteration: 59
# Expected returns of 0.13746364245307602 with risk of 0.0002274256890292311
#
# Iteration: 60
# Expected returns of 0.13746187511856744 with risk of 0.0002274138500880738
#
# Iteration: 61
# Expected returns of 0.1374598684596902 with risk of 0.00022740040294737425
#
# Iteration: 62
# Expected returns of 0.13745976848220898 with risk of 0.0002273997530747602
#
# Iteration: 63
# Expected returns of 0.1374636288745319 with risk of 0.00022742567789241046
#
# Iteration: 64
# Expected returns of 0.13746390102517428 with risk of 0.00022742751418987524
#
# Iteration: 65
# Expected returns of 0.1374640782000394 with risk of 0.00022742871081239072
#
# Iteration: 66
# Expected returns of 0.13746396803745697 with risk of 0.00022742797701328244
#
# Iteration: 67
# Expected returns of 0.1374642659774875 with risk of 0.00022742998068947615
#
# Iteration: 68
# Expected returns of 0.13746418913293978 with risk of 0.00022742946814116507
#
# Iteration: 69
# Expected returns of 0.13746510865900152 with risk of 0.00022743564286304904
#
# Iteration: 70
# Expected returns of 0.13746560968005667 with risk of 0.00022743900750919754
#
# Iteration: 71
# Expected returns of 0.1374657550190933 with risk of 0.00022743998413847586
#
# Iteration: 72
# Expected returns of 0.13746479319218824 with risk of 0.00022743352903606233
#
# Iteration: 73
# Expected returns of 0.13746498560162698 with risk of 0.0002274348212652766
#
# Iteration: 74
# Expected returns of 0.13746510763088304 with risk of 0.00022743564096705266
#
# Iteration: 75
# Expected returns of 0.13746518652614304 with risk of 0.00022743617091688494
#
# Iteration: 76
# Expected returns of 0.1374651865608415 with risk of 0.00022743617158985444
#
# Iteration: 77
# Expected returns of 0.13746517604932063 with risk of 0.00022743610127439005
#
# Iteration: 78
# Expected returns of 0.13746517965217878 with risk of 0.0002274361255506785
#
# Iteration: 79
# Expected returns of 0.1374653300024016 with risk of 0.00022743713485720747
#
# Iteration: 80
# Expected returns of 0.13746539621457937 with risk of 0.00022743757934928516
#
# Iteration: 81
# Expected returns of 0.13746556862185624 with risk of 0.00022743873662919856
#
# Iteration: 82
# Expected returns of 0.1374656735699019 with risk of 0.00022743944119037358
#
# Iteration: 83
# Expected returns of 0.13746580534985953 with risk of 0.00022744032580402588
#
# Iteration: 84
# Expected returns of 0.13746580230476702 with risk of 0.00022744030540963484
#
# Iteration: 85
# Expected returns of 0.13746614274264288 with risk of 0.000227442590664516
#
# Iteration: 86
# Expected returns of 0.13746593868484336 with risk of 0.00022744122102616882
#
# Iteration: 87
# Expected returns of 0.13746605596389494 with risk of 0.00022744200832674945
#
# Iteration: 88
# Expected returns of 0.13746606559469296 with risk of 0.00022744207308307562
#
# Iteration: 89
# Expected returns of 0.13746581038049538 with risk of 0.00022744036001696305
#
# Iteration: 90
# Expected returns of 0.13746581331188773 with risk of 0.0002274403797301672
#
# Iteration: 91
# Expected returns of 0.13746582840935082 with risk of 0.0002274404811189925
#
# Iteration: 92
# Expected returns of 0.1374656983253995 with risk of 0.00022743960795195643
#
# Iteration: 93
# Expected returns of 0.1374657326189219 with risk of 0.00022743983816465863
#
# Iteration: 94
# Expected returns of 0.13746580078870269 with risk of 0.00022744029577325114
#
# Iteration: 95
# Expected returns of 0.13746566302747026 with risk of 0.0002274393710606443
#
# Iteration: 96
# Expected returns of 0.1374656333927132 with risk of 0.00022743917214540846
#
# Iteration: 97
# Expected returns of 0.13746561138556773 with risk of 0.00022743902442899557
#
# Iteration: 98
# Expected returns of 0.13746561328265217 with risk of 0.0002274390371691734
#
# Iteration: 99
# Expected returns of 0.13746561913841002 with risk of 0.0002274390764794949
#
# Iteration: 100
# Expected returns of 0.13746564845925346 with risk of 0.00022743927329930188
#
# Optimal Solution Reached or Number of Maximum Iterations Reached

# %% [markdown]
# Weights and their Returns:

# %%
print('Weight allotted to each stock under the constraints applied:\n')
[print(hist_stock_returns.columns[i],':',elite[0][i]) for i in list(range(6))]

print('\nExpected returns of {} % with risk of {}\n '.format(Expected_returns*100,Expected_risk))

print("Fitness Function Value = ", + fitness_fuction(elite[5]))

plt.figure(figsize = (10,10))
plt.pie(elite[0], labels = hist_stock_returns.columns)
plt.legend()
plt.show()

plt.scatter(risk_list, returns_list)
plt.ylabel('Expected Returns')
plt.xlabel('Expected Risk')
plt.title('Portfolio Optimization')
plt.show()
# Out:
# Weight allotted to each stock under the constraints applied:
#
# MRF : 0.0
# INFOSYS : 0.25000000000490247
# RELIANCE : 0.13033784866617246
# COAL : 0.11966215131912013
# SBI : 0.25000000000490247
# TITAN : 0.25000000000490247
#
# Expected returns of 13.746564845925347 % with risk of 0.00022743927329930188
#
# Fitness Function Value =  4.4934184995949265

# %% [markdown]
# The given process involves the creation of two offspring, represented as one-dimensional arrays, from two parent arrays. The offspring arrays are created using the following equations:
#
# - Offspring A = α * Parent1 + (1 - α) * Parent2
#
# - Offspring B = (1 - α) * Parent1 + α * Parent2
#
# Here, the value of α is a randomly generated number between 0 and 1. The input to this process is two parent arrays, and the output is two offspring arrays, each represented as a one-dimensional array.

# %%
def Arithmetic_crossover(parent1,parent2):
    alpha = np.random.rand()
    child1 = alpha * parent1 + (1-alpha) * parent2
    child2 = (1-alpha) * parent1 + alpha * parent2
    return child1,child2

# %%
Arithmetic_crossover(population[2],population[3])
elite=Select_elite_population(population)
next_generation(100,elite,Arithmetic_crossover)[:3]
# Out:
# [array([0.        , 0.25      , 0.25      , 0.11966223, 0.25      ,
#         0.13033777]),
#  array([0.        , 0.25      , 0.25      , 0.11966217, 0.13033783,
#         0.25      ]),
#  array([0.        , 0.25      , 0.13033781, 0.11966219, 0.25      ,
#         0.25      ])]

# %%
n=6 
pop_size=100 
population = np.array([chromosome(n) for _ in range(pop_size)])
elite = Select_elite_population(population)

iteration=0 
Expected_returns=0
Expected_risk=1

returns_list = []
risk_list = []

while ( (Expected_returns < 0.30 and Expected_risk > 0.0005) and iteration <= 100 ):
    print('Iteration:',iteration)
    population = next_generation(100,elite, Arithmetic_crossover)
    elite = Select_elite_population(population)
    Expected_returns=mean_portfolio_return(elite[0])
    Expected_risk=var_portfolio_return(elite[0])
    print('Expected returns of {} with risk of {}\n'.format(Expected_returns,Expected_risk))
    iteration+=1
    returns_list.append(Expected_returns)
    risk_list.append(Expected_risk)


print('Optimal Solution Reached or Number of Maximum Iterations Reached')
# Out:
# Iteration: 0
# Expected returns of 0.18908092554877015 with risk of 0.0014852206904024954
#
# Iteration: 1
# Expected returns of 0.152342719517216 with risk of 0.000727537296946662
#
# Iteration: 2
# Expected returns of 0.1568580295392077 with risk of 0.0006666085000087436
#
# Iteration: 3
# Expected returns of 0.18518432061326084 with risk of 0.0011769882265382807
#
# Iteration: 4
# Expected returns of 0.18321902149944425 with risk of 0.001143038311562252
#
# Iteration: 5
# Expected returns of 0.16341791164730984 with risk of 0.0007634430556022749
#
# Iteration: 6
# Expected returns of 0.16232039166649048 with risk of 0.0007486151338044027
#
# Iteration: 7
# Expected returns of 0.15618107582036228 with risk of 0.0006502852887221048
#
# Iteration: 8
# Expected returns of 0.15702610928816282 with risk of 0.0006622491345930539
#
# Iteration: 9
# Expected returns of 0.1588683178274069 with risk of 0.0006892248989855817
#
# Iteration: 10
# Expected returns of 0.15904827139457295 with risk of 0.0006919215720426536
#
# Iteration: 11
# Expected returns of 0.15910632768939498 with risk of 0.000692824996708823
#
# Iteration: 12
# Expected returns of 0.15907922704433486 with risk of 0.0006924120889873877
#
# Iteration: 13
# Expected returns of 0.15907922704433486 with risk of 0.0006924120889873877
#
# Iteration: 14
# Expected returns of 0.15907922704433486 with risk of 0.0006924120889873877
#
# Iteration: 15
# Expected returns of 0.1590796130038638 with risk of 0.000692418491452104
#
# Iteration: 16
# Expected returns of 0.1590809032037452 with risk of 0.0006924399731075047
#
# Iteration: 17
# Expected returns of 0.1590827975488901 with risk of 0.0006924710663735439
#
# Iteration: 18
# Expected returns of 0.1590784176732995 with risk of 0.0006924039091842932
#
# Iteration: 19
# Expected returns of 0.15908052338662643 with risk of 0.0006924368183332894
#
# Iteration: 20
# Expected returns of 0.15908065909208247 with risk of 0.0006924390061331057
#
# Iteration: 21
# Expected returns of 0.1590807056723481 with risk of 0.000692439738189817
#
# Iteration: 22
# Expected returns of 0.15908109905533352 with risk of 0.00069244592377821
#
# Iteration: 23
# Expected returns of 0.15908111065579306 with risk of 0.0006924461116218023
#
# Iteration: 24
# Expected returns of 0.15908111582810036 with risk of 0.0006924461952914464
#
# Iteration: 25
# Expected returns of 0.1590811277958774 with risk of 0.000692446388502398
#
# Iteration: 26
# Expected returns of 0.15908113207779448 with risk of 0.0006924464574627719
#
# Iteration: 27
# Expected returns of 0.15908113220256564 with risk of 0.0006924464596029601
#
# Iteration: 28
# Expected returns of 0.15908113526078982 with risk of 0.0006924465084558939
#
# Iteration: 29
# Expected returns of 0.15908113621620054 with risk of 0.0006924465236338726
#
# Iteration: 30
# Expected returns of 0.15908113663666923 with risk of 0.0006924465303160248
#
# Iteration: 31
# Expected returns of 0.15908113678262895 with risk of 0.0006924465326774544
#
# Iteration: 32
# Expected returns of 0.15908113682885774 with risk of 0.0006924465334253753
#
# Iteration: 33
# Expected returns of 0.15908113685470365 with risk of 0.0006924465338347075
#
# Iteration: 34
# Expected returns of 0.15908113688457196 with risk of 0.0006924465343143239
#
# Iteration: 35
# Expected returns of 0.15908113693461695 with risk of 0.0006924465351215237
#
# Iteration: 36
# Expected returns of 0.15908113699093362 with risk of 0.0006924465360121229
#
# Iteration: 37
# Expected returns of 0.15908113700300536 with risk of 0.0006924465362028575
#
# Iteration: 38
# Expected returns of 0.15908113699843374 with risk of 0.0006924465361328519
#
# Iteration: 39
# Expected returns of 0.15908113699843374 with risk of 0.0006924465361328519
#
# Iteration: 40
# Expected returns of 0.1590811369988546 with risk of 0.0006924465361395115
#
# Iteration: 41
# Expected returns of 0.1590811369990463 with risk of 0.0006924465361425334
#
# Iteration: 42
# Expected returns of 0.15908113699919155 with risk of 0.000692446536144877
#
# Iteration: 43
# Expected returns of 0.15908113699936358 with risk of 0.0006924465361475987
#
# Iteration: 44
# Expected returns of 0.15908113699946302 with risk of 0.0006924465361492034
#
# Iteration: 45
# Expected returns of 0.15908113699948545 with risk of 0.0006924465361495668
#
# Iteration: 46
# Expected returns of 0.15908113699954188 with risk of 0.0006924465361504793
#
# Iteration: 47
# Expected returns of 0.15908113699954235 with risk of 0.0006924465361504862
#
# Iteration: 48
# Expected returns of 0.15908113699955 with risk of 0.0006924465361506094
#
# Iteration: 49
# Expected returns of 0.15908113699955934 with risk of 0.0006924465361507551
#
# Iteration: 50
# Expected returns of 0.15908113699956508 with risk of 0.000692446536150847
#
# Iteration: 51
# Expected returns of 0.159081136999564 with risk of 0.0006924465361508297
#
# Iteration: 52
# Expected returns of 0.15908113699957008 with risk of 0.0006924465361509233
#
# Iteration: 53
# Expected returns of 0.1590811369995682 with risk of 0.0006924465361508947
#
# Iteration: 54
# Expected returns of 0.15908113699956908 with risk of 0.0006924465361509077
#
# Iteration: 55
# Expected returns of 0.15908113699956983 with risk of 0.0006924465361509199
#
# Iteration: 56
# Expected returns of 0.15908113699956988 with risk of 0.0006924465361509207
#
# Iteration: 57
# Expected returns of 0.1590811369995705 with risk of 0.0006924465361509303
#
# Iteration: 58
# Expected returns of 0.1590811369995703 with risk of 0.0006924465361509268
#
# Iteration: 59
# Expected returns of 0.15908113699957072 with risk of 0.0006924465361509338
#
# Iteration: 60
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 61
# Expected returns of 0.1590811369995701 with risk of 0.0006924465361509242
#
# Iteration: 62
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 63
# Expected returns of 0.15908113699957008 with risk of 0.0006924465361509233
#
# Iteration: 64
# Expected returns of 0.1590811369995701 with risk of 0.0006924465361509233
#
# Iteration: 65
# Expected returns of 0.15908113699956988 with risk of 0.0006924465361509207
#
# Iteration: 66
# Expected returns of 0.15908113699957005 with risk of 0.0006924465361509233
#
# Iteration: 67
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 68
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 69
# Expected returns of 0.15908113699956997 with risk of 0.0006924465361509216
#
# Iteration: 70
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 71
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 72
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 73
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 74
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 75
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 76
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 77
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 78
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 79
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 80
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 81
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 82
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 83
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 84
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 85
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 86
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 87
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 88
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 89
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 90
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 91
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 92
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 93
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 94
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 95
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 96
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 97
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 98
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 99
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Iteration: 100
# Expected returns of 0.15908113699956994 with risk of 0.0006924465361509216
#
# Optimal Solution Reached or Number of Maximum Iterations Reached

# %%
print('Weight allotted to each stock under the constraints applied:\n')
[print(hist_stock_returns.columns[i],':',elite[0][i]) for i in list(range(6))]

print('\nExpected returns of {} % with risk of {}\n '.format(Expected_returns*100,Expected_risk))

print("Fitness Function Value = ", + fitness_fuction(elite[5]))

plt.figure(figsize = (10,10))
plt.pie(elite[0], labels = hist_stock_returns.columns)
plt.legend()
plt.show()

plt.scatter(risk_list, returns_list)
plt.ylabel('Expected Returns')
plt.xlabel('Expected Risk')
plt.title('Portfolio Optimization')
plt.show()
# Out:
# Weight allotted to each stock under the constraints applied:
#
# MRF : 0.04607359854669502
# INFOSYS : 0.1834649107323177
# RELIANCE : 0.1297158792042105
# COAL : 0.15951117887562383
# SBI : 0.24907598711797946
# TITAN : 0.23215844552317355
#
# Expected returns of 15.908113699956994 % with risk of 0.0006924465361509216
#
# Fitness Function Value =  3.3966652751757938

# %%
covariance = np.array([[0.000000, 0.045393, 0.027916, 0.024127, -0.079078, 0.014362],
                      [0.045393, 0.000000, -0.000718, 0.004381, -0.023178, -0.005554],
                      [0.027916, -0.000718, 0.000000, 0.002510, -0.013841, 0.007330],
                      [0.024127, 0.004381, 0.002510, 0.000000, -0.011042, 0.005700],
                      [-0.079078, -0.023178, -0.013841, -0.011042, 0.000000, -0.007211],
                      [0.014362, -0.005554, 0.007330, 0.005700, -0.007211, 0.000000]])

expected_returns = np.array([0.08, 0.12, 0.06, 0.09, 0.11, 0.07])
portfolio_weights = np.ones(len(expected_returns))/len(expected_returns)
portfolio_return = np.dot(expected_returns, portfolio_weights)
portfolio_variance = np.dot(np.dot(portfolio_weights, covariance), portfolio_weights)

print("Portfolio Expected Return:", portfolio_return*100)

num_portfolios = 10000
portfolio_returns = np.zeros(num_portfolios)
portfolio_variances = np.zeros(num_portfolios)

for i in range(num_portfolios):
    weights = np.random.random(len(expected_returns))
    weights /= np.sum(weights)
    
    portfolio_returns[i] = np.dot(expected_returns, weights)
    portfolio_variances[i] = np.sqrt(np.dot(np.dot((weights), abs(covariance)), (weights)))
    
plt.figure(figsize=(12,8))
plt.scatter(portfolio_variances, portfolio_returns, c=portfolio_returns/portfolio_variances)
plt.xlabel('Portfolio Volatility')
plt.ylabel('Portfolio Expected Return')
plt.colorbar(label='Sharpe Ratio')
plt.title('Markowitz Bullet')
plt.show()
# Out:
# Portfolio Expected Return: 8.833333333333332
